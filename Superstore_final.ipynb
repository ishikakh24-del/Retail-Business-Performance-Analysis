# %%
# Importing Libraries

# %%
import pandas as pd
import numpy as np

# %%
# Loading the dataset

# %%
df = pd.read_csv("Superstore_cleaned.csv")

# %%
# Checking if loaded:

# %%
df.head()
# Out:
#          Order Id  Order Date Quarter Order Month  Order Year Late shipment  \
# 0  CA-2016-152156   11/8/2016      Q4         Nov      2016.0            No
# 1  CA-2016-152156   11/8/2016      Q4         Nov      2016.0            No
# 2  CA-2016-138688   6/12/2016      Q2         Jun      2016.0            No
# 3  US-2015-108966  10/11/2015      Q4         Oct      2015.0           Yes
# 4  US-2015-108966  10/11/2015      Q4         Oct      2015.0           Yes
#
#    delivery days   Ship Date       Ship Mode Customer ID  ...  \
# 0            3.0  11/11/2016    Second Class    CG-12520  ...
# 1            3.0  11/11/2016    Second Class    CG-12520  ...
# 2            4.0   6/16/2016    Second Class    DV-13045  ...
# 3            7.0  10/18/2015  Standard Class    SO-20335  ...
# 4            7.0  10/18/2015  Standard Class    SO-20335  ...
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# ...

# %%
# Understand dataset structure

# %%
df.shape
# Out:
# (9994, 27)

# %%
df.columns
# Out:
# Index(['Order Id', 'Order Date', 'Quarter', 'Order Month', 'Order Year',
#        'Late shipment', 'delivery days', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount Bucket', 'Discount',
#        'Profit', 'Profit Margin'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 27 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order Id         9986 non-null   str
#  1   Order Date       9986 non-null   str
#  2   Quarter          9986 non-null   str
#  3   Order Month      9986 non-null   str
#  4   Order Year       9986 non-null   float64
#  5   Late shipment    9986 non-null   str
#  6   delivery days    9986 non-null   float64
#  7   Ship Date        9986 non-null   str
#  8   Ship Mode        9986 non-null   str
#  9   Customer ID      9986 non-null   str
#  10  Customer Name    9986 non-null   str
#  11  Segment          9986 non-null   str
#  12  Country          9986 non-null   str
#  13  City             9986 non-null   str
#  14  State            9986 non-null   str
#  15  Postal Code      9986 non-null   float64
#  16  Region           9986 non-null   str
#  17  Product ID       9986 non-null   str
# ...

# %%
df.isnull().sum()
# Out:
# Order Id           8
# Order Date         8
# Quarter            8
# Order Month        8
# Order Year         8
# Late shipment      8
# delivery days      8
# Ship Date          8
# Ship Mode          8
# Customer ID        8
# Customer Name      8
# Segment            8
# Country            8
# City               8
# State              8
# Postal Code        8
# Region             8
# Product ID         8
# Category           8
# Sub-Category       8
# Product Name       8
# Sales              8
# Quantity           8
# Discount Bucket    8
# Discount           8
# Profit             8
# Profit Margin      8
# dtype: int64
